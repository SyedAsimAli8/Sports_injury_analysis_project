# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics = pd.read_csv("Downloads/metrics.csv")

# %%
metrics.head()
# Out:
#    athlete_id        date        metric  value
# 0           1  2016-05-01  hip_mobility     36
# 1           1  2016-05-02  hip_mobility     36
# 2           1  2016-05-03  hip_mobility     56
# 3           1  2016-05-04  hip_mobility     24
# 4           1  2016-05-05  hip_mobility     35

# %%
metrics.describe(include='all')
# Out:
#          athlete_id        date        metric         value
# count   43800.00000       43800         43800  43800.000000
# unique          NaN         730             2           NaN
# top             NaN  2018-04-30  hip_mobility           NaN
# freq            NaN          60         21900           NaN
# mean       15.50000         NaN           NaN    124.974338
# std         8.65554         NaN           NaN    107.841666
# min         1.00000         NaN           NaN   -108.000000
# 25%         8.00000         NaN           NaN     39.000000
# 50%        15.50000         NaN           NaN     56.000000
# 75%        23.00000         NaN           NaN    213.000000
# max        30.00000         NaN           NaN    487.000000

# %%
metrics['date'] = metrics['date'].astype('datetime64[ns]')
metrics.dtypes
# Out:
# athlete_id             int64
# date          datetime64[ns]
# metric                object
# value                  int64
# dtype: object

# %%
workload = pd.read_csv("Downloads/game_workload.csv")

# %%
workload.head()
# Out:
#    athlete_id        date  game_workload
# 0           1  2016-05-05            402
# 1           1  2016-05-08            365
# 2           1  2016-05-11            457
# 3           1  2016-05-16            405
# 4           1  2016-05-20            407

# %%
workload.describe(include='all')
# Out:
#          athlete_id        date  game_workload
# count   2400.000000        2400    2400.000000
# unique          NaN         706            NaN
# top             NaN  2017-03-26            NaN
# freq            NaN           9            NaN
# mean      15.649167         NaN     400.481667
# std        8.735438         NaN      47.991824
# min        1.000000         NaN     225.000000
# 25%        8.000000         NaN     368.000000
# 50%       16.000000         NaN     400.000000
# 75%       23.000000         NaN     433.250000
# max       30.000000         NaN     534.000000

# %%
workload['date'] = workload['date'].astype('datetime64[ns]')
workload.dtypes
# Out:
# athlete_id                int64
# date             datetime64[ns]
# game_workload             int64
# dtype: object

# %%
injuries = pd.read_csv("Downloads/injuries.csv")

# %%
injuries.head()
# Out:
#    athlete_id        date
# 0           1  2016-05-11
# 1           1  2016-05-16
# 2           1  2016-07-28
# 3           1  2016-11-11
# 4           1  2016-12-16

# %%
injuries.describe(include = 'all')
# Out:
#         athlete_id        date
# count   137.000000         137
# unique         NaN         126
# top            NaN  2016-05-16
# freq           NaN           4
# mean     15.605839         NaN
# std       9.653068         NaN
# min       1.000000         NaN
# 25%       6.000000         NaN
# 50%      18.000000         NaN
# 75%      24.000000         NaN
# max      30.000000         NaN

# %%
injuries['date'] = injuries['date'].astype('datetime64[ns]')
injuries.dtypes
# Out:
# athlete_id             int64
# date          datetime64[ns]
# dtype: object

# %%
"""Creating a new column named injury with all values as yes"""
injuries["injury"] = "Yes"

# %%
injuries.head()
# Out:
#    athlete_id       date injury
# 0           1 2016-05-11    Yes
# 1           1 2016-05-16    Yes
# 2           1 2016-07-28    Yes
# 3           1 2016-11-11    Yes
# 4           1 2016-12-16    Yes

# %%
"""Merging the workload and injuries dataframes"""
games_data = pd.merge(workload,injuries,  how='left', left_on=['athlete_id','date'], right_on = ['athlete_id','date'])

# %%
games_data["injury"].fillna("No", inplace = True)
#playersData["game_workload"].fillna(0, inplace = True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11144\3098241866.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   games_data["injury"].fillna("No", inplace = True)

# %%
games_data.head()
# Out:
#    athlete_id       date  game_workload injury
# 0           1 2016-05-05            402     No
# 1           1 2016-05-08            365     No
# 2           1 2016-05-11            457    Yes
# 3           1 2016-05-16            405    Yes
# 4           1 2016-05-20            407     No

# %%
metrics.head()
# Out:
#    athlete_id       date        metric  value
# 0           1 2016-05-01  hip_mobility     36
# 1           1 2016-05-02  hip_mobility     36
# 2           1 2016-05-03  hip_mobility     56
# 3           1 2016-05-04  hip_mobility     24
# 4           1 2016-05-05  hip_mobility     35

# %%
"""Recording metric type as two seperate columns i.e transposing the groin_squeeze and hip_mobility rows into columns"""
new_metrics_df = metrics.pivot_table('value', ['athlete_id', 'date'], 'metric').reset_index()

# %%
new_metrics_df.head()
# Out:
# metric  athlete_id       date  groin_squeeze  hip_mobility
# 0                1 2016-05-01          297.0          36.0
# 1                1 2016-05-02          274.0          36.0
# 2                1 2016-05-03          291.0          56.0
# 3                1 2016-05-04          260.0          24.0
# 4                1 2016-05-05          284.0          35.0

# %%
new_metrics_df.shape
# Out:
# (21900, 4)

# %%
final_data = pd.merge(games_data,new_metrics_df,  how='left', left_on=['athlete_id','date'], right_on = ['athlete_id','date'])

# %%
final_data.shape
# Out:
# (2400, 6)

# %%
final_data.head()
# Out:
#    athlete_id       date  game_workload injury  groin_squeeze  hip_mobility
# 0           1 2016-05-05            402     No          284.0          35.0
# 1           1 2016-05-08            365     No          250.0          41.0
# 2           1 2016-05-11            457    Yes          331.0          33.0
# 3           1 2016-05-16            405    Yes          260.0          38.0
# 4           1 2016-05-20            407     No          378.0          60.0

# %%
final_data['rest_period'] = final_data.groupby('athlete_id')['date'].diff()

# %%
final_data.head()
# Out:
#    athlete_id       date  game_workload injury  groin_squeeze  hip_mobility  \
# 0           1 2016-05-05            402     No          284.0          35.0
# 1           1 2016-05-08            365     No          250.0          41.0
# 2           1 2016-05-11            457    Yes          331.0          33.0
# 3           1 2016-05-16            405    Yes          260.0          38.0
# 4           1 2016-05-20            407     No          378.0          60.0
#
#   rest_period
# 0         NaT
# 1      3 days
# 2      3 days
# 3      5 days
# 4      4 days

# %%
first_day = '2016-05-01'
date_object = pd.to_datetime(first_day)

# %%
final_data["rest_period"].fillna(final_data['date'] - date_object, inplace = True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11144\3327428391.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_data["rest_period"].fillna(final_data['date'] - date_object, inplace = True)

# %%
final_data.head()
# Out:
#    athlete_id       date  game_workload injury  groin_squeeze  hip_mobility  \
# 0           1 2016-05-05            402     No          284.0          35.0
# 1           1 2016-05-08            365     No          250.0          41.0
# 2           1 2016-05-11            457    Yes          331.0          33.0
# 3           1 2016-05-16            405    Yes          260.0          38.0
# 4           1 2016-05-20            407     No          378.0          60.0
#
#   rest_period
# 0      4 days
# 1      3 days
# 2      3 days
# 3      5 days
# 4      4 days

# %%
"""Converting the column into day format"""
final_data['rest_period'] = final_data['rest_period'].astype('timedelta64[ns]')

# %%
final_data.head()
# Out:
#    athlete_id       date  game_workload injury  groin_squeeze  hip_mobility  \
# 0           1 2016-05-05            402     No          284.0          35.0
# 1           1 2016-05-08            365     No          250.0          41.0
# 2           1 2016-05-11            457    Yes          331.0          33.0
# 3           1 2016-05-16            405    Yes          260.0          38.0
# 4           1 2016-05-20            407     No          378.0          60.0
#
#   rest_period
# 0      4 days
# 1      3 days
# 2      3 days
# 3      5 days
# 4      4 days

# %% [markdown]
# ## Statistical Analysis
# Preparing the dataframe for statistical analysis/ machine learning by adding/removing the categorical variables

# %%
final_data.injury.replace(to_replace=['No', 'Yes'], value=[0, 1], inplace = True)
final_data = final_data[['injury','athlete_id','date','game_workload','groin_squeeze','hip_mobility','rest_period']]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11144\1835743825.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_data.injury.replace(to_replace=['No', 'Yes'], value=[0, 1], inplace = True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_11144\1835743825.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   final_data.injury.replace(to_replace=['No', 'Yes'], value=[0, 1], inplace = True)

# %%
final_data.head()
# Out:
#    injury  athlete_id       date  game_workload  groin_squeeze  hip_mobility  \
# 0       0           1 2016-05-05            402          284.0          35.0
# 1       0           1 2016-05-08            365          250.0          41.0
# 2       1           1 2016-05-11            457          331.0          33.0
# 3       1           1 2016-05-16            405          260.0          38.0
# 4       0           1 2016-05-20            407          378.0          60.0
#
#   rest_period
# 0      4 days
# 1      3 days
# 2      3 days
# 3      5 days
# 4      4 days

# %%
"""Creating dummy variables for categorical Athelete Ids"""
dummy_variables = pd.get_dummies(final_data['athlete_id'])
ready_data = pd.concat([final_data,dummy_variables], axis=1)

# %%
ready_data.head()
# Out:
#    injury  athlete_id       date  game_workload  groin_squeeze  hip_mobility  \
# 0       0           1 2016-05-05            402          284.0          35.0
# 1       0           1 2016-05-08            365          250.0          41.0
# 2       1           1 2016-05-11            457          331.0          33.0
# 3       1           1 2016-05-16            405          260.0          38.0
# 4       0           1 2016-05-20            407          378.0          60.0
#
#   rest_period     1      2      3  ...     21     22     23     24     25  \
# 0      4 days  True  False  False  ...  False  False  False  False  False
# 1      3 days  True  False  False  ...  False  False  False  False  False
# 2      3 days  True  False  False  ...  False  False  False  False  False
# 3      5 days  True  False  False  ...  False  False  False  False  False
# 4      4 days  True  False  False  ...  False  False  False  False  False
#
#       26     27     28     29     30
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False
#
# [5 rows x 37 columns]

# %%
ready_data.drop('athlete_id', axis = 1, inplace= True)
ready_data.drop('date', axis = 1, inplace = True)

# %%
ready_data.head()
# Out:
#    injury  game_workload  groin_squeeze  hip_mobility rest_period     1  \
# 0       0            402          284.0          35.0      4 days  True
# 1       0            365          250.0          41.0      3 days  True
# 2       1            457          331.0          33.0      3 days  True
# 3       1            405          260.0          38.0      5 days  True
# 4       0            407          378.0          60.0      4 days  True
#
#        2      3      4      5  ...     21     22     23     24     25     26  \
# 0  False  False  False  False  ...  False  False  False  False  False  False
# 1  False  False  False  False  ...  False  False  False  False  False  False
# 2  False  False  False  False  ...  False  False  False  False  False  False
# 3  False  False  False  False  ...  False  False  False  False  False  False
# 4  False  False  False  False  ...  False  False  False  False  False  False
#
#       27     28     29     30
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
#
# [5 rows x 35 columns]
